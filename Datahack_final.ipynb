# %%
# !wget https://nuws.co/datahack-dataset
# Out:
# --2021-10-09 11:58:46--  https://nuws.co/datahack-dataset
# Resolving nuws.co (nuws.co)... 52.72.49.79
# Connecting to nuws.co (nuws.co)|52.72.49.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://numadic-datatrax.s3.ap-south-1.amazonaws.com/numadic-customer-transaction-prediction.tar.xz [following]
# --2021-10-09 11:58:46--  https://numadic-datatrax.s3.ap-south-1.amazonaws.com/numadic-customer-transaction-prediction.tar.xz
# Resolving numadic-datatrax.s3.ap-south-1.amazonaws.com (numadic-datatrax.s3.ap-south-1.amazonaws.com)... 52.219.158.30
# Connecting to numadic-datatrax.s3.ap-south-1.amazonaws.com (numadic-datatrax.s3.ap-south-1.amazonaws.com)|52.219.158.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 224010468 (214M) [application/x-www-form-urlencoded]
# Saving to: ‘datahack-dataset’
#
# datahack-dataset    100%[===================>] 213.63M  11.8MB/s    in 21s
#
# ...

# %%
# !tar -xvf "/content/datahack-dataset" -C "/content/"
# Out:
# numadic-customer-transaction-prediction/
# numadic-customer-transaction-prediction/test.csv
# numadic-customer-transaction-prediction/train.csv

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/numadic-customer-transaction-prediction/train.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %%
data.head()
# Out:
#    ID_code  target    var_0   var_1  ...  var_196  var_197  var_198  var_199
# 0  train_0       0   8.9255 -6.7863  ...   7.8784   8.5635  12.7803  -1.0914
# 1  train_1       0  11.5006 -4.1473  ...   8.1267   8.7889  18.3560   1.9518
# 2  train_2       0   8.6093 -2.7457  ...  -6.5213   8.2675  14.7222   0.3965
# 3  train_3       0  11.0604 -2.1518  ...  -2.9275  10.2922  17.9697  -8.9996
# 4  train_4       0   9.8369 -1.4834  ...   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
data.describe()
# Out:
#               target          var_0  ...        var_198        var_199
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean        0.100490      10.679914  ...      15.870720      -3.326537
# std         0.300653       3.040051  ...       3.010945      10.438015
# min         0.000000       0.408400  ...       6.299300     -38.852800
# 25%         0.000000       8.453850  ...      13.829700     -11.208475
# 50%         0.000000      10.524750  ...      15.934050      -2.819550
# 75%         0.000000      12.758200  ...      18.064725       4.836800
# max         1.000000      20.315000  ...      26.079100      28.500700
#
# [8 rows x 201 columns]

# %%
data.drop(['ID_code'],axis=1,inplace=True)
data.head()
# Out:
#    target    var_0   var_1    var_2  ...  var_196  var_197  var_198  var_199
# 0       0   8.9255 -6.7863  11.9081  ...   7.8784   8.5635  12.7803  -1.0914
# 1       0  11.5006 -4.1473  13.8588  ...   8.1267   8.7889  18.3560   1.9518
# 2       0   8.6093 -2.7457  12.0805  ...  -6.5213   8.2675  14.7222   0.3965
# 3       0  11.0604 -2.1518   8.9522  ...  -2.9275  10.2922  17.9697  -8.9996
# 4       0   9.8369 -1.4834  12.8746  ...   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 201 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(y=data.target ,data=data)
plt.xlabel("Count of each Target class")
plt.ylabel("Target classes")
plt.show()

# %%
X = data.drop(['target'],axis=1)
Y = data.target

# %%
X.head()
# Out:
#      var_0   var_1    var_2   var_3  ...  var_196  var_197  var_198  var_199
# 0   8.9255 -6.7863  11.9081  5.0930  ...   7.8784   8.5635  12.7803  -1.0914
# 1  11.5006 -4.1473  13.8588  5.3890  ...   8.1267   8.7889  18.3560   1.9518
# 2   8.6093 -2.7457  12.0805  7.8928  ...  -6.5213   8.2675  14.7222   0.3965
# 3  11.0604 -2.1518   8.9522  7.1957  ...  -2.9275  10.2922  17.9697  -8.9996
# 4   9.8369 -1.4834  12.8746  6.6375  ...   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 200 columns]

# %%
Y.shape
# Out:
# (200000,)

# %%
from sklearn.model_selection import train_test_split 
# Feature Scaling is used because we don't want one independent variable dominating the other and it makes computations easy
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.33, random_state = 0)

# %%
# data = pd.read_csv("/content/numadic-customer-transaction-prediction/test.csv")
# data.drop(['ID_code'],axis=1,inplace=True)
# data.describe()
# data.head()

# %%
X_train.shape
# Out:
# (134000, 200)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
classifier = DecisionTreeClassifier(criterion="entropy", max_depth=10) #“entropy” for the information gain.
classifier.fit(X_train, y_train) #training the classifier
y_pred = classifier.predict(X_test) #making precdictions

# %%
feat_importances = pd.DataFrame(classifier.feature_importances_, index=X.columns, columns=["Importance"])
feat_importances.sort_values(by='Importance', ascending=False, inplace=True)
feat_importances.plot(kind='bar', figsize=(200,200))

# %%
a = (feat_importances > 0)

# %%
a
# Out:
#          Importance
# var_81         True
# var_139        True
# var_12         True
# var_110        True
# var_174        True
# ...             ...
# var_17        False
# var_41        False
# var_15        False
# var_104       False
# var_129       False
#
# [200 rows x 1 columns]

# %%
b = a[a['Importance'] == True]

# %%
b=b.iloc[:,:0]
b
# Out:
# Empty DataFrame
# Columns: []
# Index: [var_81, var_139, var_12, var_110, var_174, var_53, var_26, var_109, var_146, var_6, var_80, var_166, var_190, var_34, var_133, var_165, var_179, var_99, var_76, var_184, var_170, var_44, var_21, var_0, var_2, var_115, var_164, var_40, var_13, var_91, var_1, var_119, var_95, var_192, var_172, var_78, var_102, var_162, var_130, var_188, var_108, var_92, var_135, var_149, var_22, var_198, var_169, var_9, var_155, var_18, var_93, var_56, var_73, var_148, var_186, var_175, var_75, var_103, var_199, var_173, var_118, var_144, var_39, var_124, var_183, var_48, var_176, var_177, var_82, var_61, var_147, var_160, var_85, var_58, var_51, var_193, var_112, var_140, var_63, var_167, var_42, var_3, var_71, var_123, var_86, var_84, var_150, var_158, var_33, var_32, var_121, var_47, var_87, var_65, var_5, var_157, var_178, var_142, var_156, var_62, ...]
#
# [167 rows x 0 columns]

# %%
important_features=[]

for i in b.index:
  important_features.append(i)

# %%
(important_features)
# Out:
# ['var_81',
#  'var_139',
#  'var_12',
#  'var_110',
#  'var_174',
#  'var_53',
#  'var_26',
#  'var_109',
#  'var_146',
#  'var_6',
#  'var_80',
#  'var_166',
#  'var_190',
#  'var_34',
#  'var_133',
#  'var_165',
#  'var_179',
#  'var_99',
#  'var_76',
#  'var_184',
#  'var_170',
#  'var_44',
#  'var_21',
#  'var_0',
#  'var_2',
#  'var_115',
#  'var_164',
#  'var_40',
#  'var_13',
#  'var_91',
#  'var_1',
#  'var_119',
#  'var_95',
#  'var_192',
#  'var_172',
#  'var_78',
#  'var_102',
#  'var_162',
#  'var_130',
#  'var_188',
#  'var_108',
#  'var_92',
#  'var_135',
#  'var_149',
#  'var_22',
#  'var_198',
#  'var_169',
#  'var_9',
#  'var_155',
#  'var_18',
#  'var_93',
#  'var_56',
#  'var_73',
#  'var_148',
#  'var_186',
#  'var_175',
#  'var_75',
#  'var_103',
#  'var_199',
#  'var_173',
#  'var_118',
#  'var_144',
#  'var_39',
#  'var_124',
#  'var_183',
#  'var_48',
#  'var_176',
#  'var_177',
#  'var_82',
#  'var_61',
#  'var_147',
#  'var_160',
#  'var_85',
#  'var_58',
# ...

# %%
X = X[important_features]

# %%
X.head()
# Out:
#     var_81  var_139   var_12  var_110  ...  var_37   var_88  var_138  var_52
# 0  13.8372  15.6599  14.0137   2.0323  ...  7.8871   7.9984   2.8279 -0.6940
# 1  18.1782  16.1622  14.0239   6.6203  ...  5.8434   7.9022  -1.9721 -4.1083
# 2  15.7811   8.6674  14.1929   3.2304  ...  6.9346  11.9052   3.8212  0.7268
# 3  10.5404   8.9821  13.8463   4.2827  ...  2.8521   4.5474  -2.8233  1.7895
# 4  13.3317  13.9547  13.8481  -0.1937  ...  5.8184   8.0053   2.6791 -1.4367
#
# [5 rows x 167 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.33, random_state = 0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras import regularizers
model = Sequential()
model.add(Dense(units = 164, activation = 'relu', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.l2(1e-4),
    activity_regularizer=regularizers.l2(1e-5) ,input_dim = 167))
model.add(Dropout(0.3))
model.add(Dense(units = 64, activation = 'relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.l2(1e-4),
    activity_regularizer=regularizers.l2(1e-5)))
model.add(Dropout(0.3))
model.add(Dense(units = 32, activation = 'relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.l2(1e-4),
    activity_regularizer=regularizers.l2(1e-5)))
model.add(Dropout(0.3))
model.add(Dense(units = 8, activation = 'relu',kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
    bias_regularizer=regularizers.l2(1e-4),
    activity_regularizer=regularizers.l2(1e-5)))
model.add(Dropout(0.3))
model.add(Dense(units = 1, activation = 'sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])


model.summary()
model.fit(X_train, y_train, batch_size = 1024, epochs = 30)
score, acc = model.evaluate(X_train, y_train,
                            batch_size=64)
print('Train score:', score)
print('Train accuracy:', acc)

print('*'*20)

# Evaluating on Test data
score, acc = model.evaluate(X_test, y_test,
                            batch_size=10)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 164)               27552
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 164)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                10560
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 8)                 264
# ...

# %%
df_test = pd.read_csv("/content/numadic-customer-transaction-prediction/test.csv")
df_test.head()
# Out:
#   ID_code    var_0    var_1    var_2  ...  var_196  var_197  var_198  var_199
# 0  test_0  11.0656   7.7798  12.9536  ...   4.3654  10.7200  15.4722  -8.7197
# 1  test_1   8.5304   1.2543  11.3047  ...  -1.4852   9.8714  19.1293 -20.9760
# 2  test_2   5.4827 -10.3581  10.1407  ...  -7.1086   7.0618  19.8956 -23.1794
# 3  test_3   8.5374  -1.3222  12.0220  ...   3.9567   9.2295  13.0168  -4.2108
# 4  test_4  11.7058  -0.1327  14.1295  ...  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %%
df_t = df_test.drop(['ID_code'],axis=1)
id_code = df_test.ID_code

# %%
df_t.head()
# Out:
#      var_0    var_1    var_2   var_3  ...  var_196  var_197  var_198  var_199
# 0  11.0656   7.7798  12.9536  9.4292  ...   4.3654  10.7200  15.4722  -8.7197
# 1   8.5304   1.2543  11.3047  5.1858  ...  -1.4852   9.8714  19.1293 -20.9760
# 2   5.4827 -10.3581  10.1407  7.0479  ...  -7.1086   7.0618  19.8956 -23.1794
# 3   8.5374  -1.3222  12.0220  6.5749  ...   3.9567   9.2295  13.0168  -4.2108
# 4  11.7058  -0.1327  14.1295  7.7506  ...  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 200 columns]

# %%
df_t = df_t[important_features]

# %%
final = model.predict(df_t)

# %%
final= (final>0.5)

# %%
df_med = pd.DataFrame(final, columns = ['target'])

# %%
Submission = df_med.replace({True:1,False:0})

# %%
Submission
# Out:
#        target
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 199995      0
# 199996      0
# 199997      0
# 199998      0
# 199999      0
#
# [200000 rows x 1 columns]

# %%
Submission_new = pd.concat([id_code,Submission], axis=1)

# %%
Submission_new
# Out:
#             ID_code target
# 0            test_0      0
# 1            test_1      0
# 2            test_2      0
# 3            test_3      0
# 4            test_4      0
# ...             ...    ...
# 199995  test_199995      0
# 199996  test_199996      0
# 199997  test_199997      0
# 199998  test_199998      0
# 199999  test_199999      0
#
# [200000 rows x 2 columns]

# %%
Submission_new.to_csv('datahack_result.csv')
